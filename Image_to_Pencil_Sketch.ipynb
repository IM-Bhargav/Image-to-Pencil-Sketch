# %%
import cv2
from google.colab.patches import cv2_imshow

# %%
image = cv2.imread("/content/Spydie.jpg")

# %%
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=1920x1080 at 0x7F7D3E2A4C90>

# %%
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
cv2_imshow(gray_image)
# Out:
# <PIL.Image.Image image mode=L size=1920x1080 at 0x7F7D3E2A4650>

# %%
inverted_image = 255 - gray_image
cv2_imshow(inverted_image)
# Out:
# <PIL.Image.Image image mode=L size=1920x1080 at 0x7F7D3E1D0390>

# %%
blurred = cv2.GaussianBlur(inverted_image, (21, 21), 0)

# %%
inverted_blurred = 255 - blurred
pencil_sketch = cv2.divide(gray_image, inverted_blurred, scale=256.0)
cv2_imshow(pencil_sketch)
# Out:
# <PIL.Image.Image image mode=L size=1920x1080 at 0x7F7D3E1E2550>

# %%
cv2_imshow( image)
# Out:
# <PIL.Image.Image image mode=RGB size=1920x1080 at 0x7F7D3E1E24D0>

# %%
cv2_imshow( pencil_sketch)
# Out:
# <PIL.Image.Image image mode=L size=1920x1080 at 0x7F7D3E24A150>
